# %%
# !python3 tetris_agent.py --mode play --model ./dqn_models_stats/tetrisJay-best_-9.dat
# Out:
# DQN(
#   (conv_layers): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=768, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=7, bias=True)
#   )
# )
# Action taken = 4, Reward=0.0
# o----------o
# |          |
# |   XXX    |
# |     X    |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# o----------o
# Action taken = 4, Reward=0.0
# o----------o
# |          |
# ...

# %%
# !python3 tetris_agent.py --cuda
# Out:
# DQN(
#   (conv_layers): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=768, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=7, bias=True)
#   )
# )
# 52: done 1 games, reward -5.352, eps 1.00, speed 1620.66 f/s
# 94: done 2 games, reward -4.806, eps 1.00, speed 826.34 f/s
# Best reward updated -5.352 -> -4.806
# 138: done 3 games, reward -4.870, eps 1.00, speed 874.64 f/s
# 203: done 4 games, reward -5.047, eps 1.00, speed 1801.01 f/s
# 241: done 5 games, reward -5.078, eps 1.00, speed 1365.12 f/s
# 274: done 6 games, reward -5.013, eps 1.00, speed 1326.33 f/s
# ...
