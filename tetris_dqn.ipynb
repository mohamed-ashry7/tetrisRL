# %%
# !python3 tetris_agent.py --mode play --model ./dqn_models_stats/tetrisJay-best_303.dat
# Out:
# DQN(
#   (conv_layers): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=768, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=7, bias=True)
#   )
# )
# Action taken = 5, Reward=6
# o----------o
# |     XX   |
# |     XX   |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# |          |
# o----------o
# Action taken = 5, Reward=6
# o----------o
# |          |
# |          |
# ...

# %%
# !python3 tetris_agent.py
# Out:
# DQN(
#   (conv_layers): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=768, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=7, bias=True)
#   )
# )
# 30: done 1 games, reward 137.000, eps 1.00, speed 7877.12 f/s
# Solved in 30 frames!
